# %% [markdown]
# # 01 - EDA\n\nThis notebook gives a quick, recruiter-friendly overview of the PaySim dataset and the fraud-class imbalance.

# %%
from pathlib import Path\n\nfrom src.data.load_data import load_paysim_csv\n\nDATA_PATH = Path('data/raw/PS_20174392719_1491204439457_log.csv')\ndf = load_paysim_csv(DATA_PATH)\ndf.head()

# %%
summary = {\n    'rows': len(df),\n    'fraud_rate': float(df['isFraud'].mean()),\n    'transaction_types': df['type'].value_counts().to_dict(),\n}\nsummary
