# %% [markdown]
# # 03 - Model Experiments\n\nThis notebook calls the code-first training pipeline, then inspects the exported metrics that later feed the portfolio README.

# %%
from pathlib import Path\nimport json\n\nfrom src.models.train import train_and_evaluate\n\nDATA_PATH = Path('data/raw/PS_20174392719_1491204439457_log.csv')\nOUTPUT_DIR = Path('reports/metrics/notebook_run')\n\nresults = train_and_evaluate(DATA_PATH, sample_size=50000, output_dir=OUTPUT_DIR)\nresults.keys()

# %%
metrics_path = Path('reports/metrics/notebook_run/model_comparison.json')\njson.loads(metrics_path.read_text(encoding='utf-8'))
